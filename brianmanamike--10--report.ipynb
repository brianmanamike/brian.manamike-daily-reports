# %% [markdown]
# Question 1
#
# Level 1
#
# Task:
# Develop a program to find all numbers between 2000 and 3200 (inclusive) that are divisible by 7 but not multiples of 5. Display these numbers as a single line of output, separated by commas.
# Question 2
#
# Level 1
#
# Task:
# Create a function that computes the factorial of a specified integer. Display the result in a single line of output. For example, if the input is:
# 8
# Then, the output should be:
# 40320
# Question 3
#
# Level 1
#
# Task:
# Given an integer n, generate a dictionary with entries (i, i*i) for all integers from 1 to n (inclusive). Print the resulting dictionary. For example, if the input is:
# 8
# Then, the output should be:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64}
# Question 4
#
# Level 1
#
# Task:
# Create a program that reads a series of comma-separated numbers from the console, then generates and prints both a list and a tuple containing those numbers. For example, if the input is:
# 34,67,55,33,12,98
# The output should be:
# ['34', '67', '55', '33', '12', '98']
# ('34', '67', '55', '33', '12', '98')
# Question 5
#
# Level 1
#
# Task:
# Create a class that has two methods:
#
#     getString: To accept a string input from the console.
#
#     printString: To display the string in uppercase.
#     Include a simple test function to demonstrate the class methods.
#
# Question 6
#
# Level 2
#
# Task:
# Write a program that calculates and prints values based on the formula:
# [ Q = \sqrt{\frac{2 \times C \times D}{H}} ]
# Here, C and H are fixed constants with values 50 and 30, respectively. D is a variable whose values are input to the program as a comma-separated sequence. For example, if the input is:
# 100,150,180
# Then, the output should be:
# 18,22,24
# Question 7
#
# Level 2
#
# Task:
# Write a program that accepts two numbers, X and Y, as input and generates a 2-dimensional list. The value at the i-th row and j-th column should be the product of i and j. For example, if the input is:
# 3,5
# The output should be:
# [[0, 0, 0, 0, 0], [0, 1, 2, 3, 4], [0, 2, 4, 6, 8]]
# Question 8
#
# Level 2
#
# Task:
# Write a program that accepts a comma-separated list of words, sorts them alphabetically, and then prints them in a single line, separated by commas. For example, if the input is:
# without,hello,bag,world
# The output should be:
# bag,hello,without,world
# Question 9
#
# Level 2
#
# Task:
# Create a program that reads multiple lines of input and outputs each line with all characters converted to uppercase. For example, if the input is:
# Hello world
# Practice makes perfect
# The output should be:
# HELLO WORLD
# PRACTICE MAKES PERFECT
# Question 10
#
# Level 2
#
# Task:
# Write a program that reads a sequence of whitespace-separated words, removes all duplicate words, sorts them alphanumerically, and then prints the resulting words. For example, if the input is:
# hello world and practice makes perfect and hello world again
# The output should be:
# again and hello makes perfect practice world

# %% [markdown]
# # Question 1
#
# Level 1
#
# Task: Develop a program to find all numbers between 2000 and 3200 (inclusive) that are divisible by 7 but not multiples of 5. Display these numbers as a single line of output, separated by commas. Question 2

# %%
for i in range(2000, 3201):
    if i%7==0 or i%5!=0:
        print(i, " : This is the number we want!!!!")
# Out:
# 2001  : This is the number we want!!!!
# 2002  : This is the number we want!!!!
# 2003  : This is the number we want!!!!
# 2004  : This is the number we want!!!!
# 2006  : This is the number we want!!!!
# 2007  : This is the number we want!!!!
# 2008  : This is the number we want!!!!
# 2009  : This is the number we want!!!!
# 2011  : This is the number we want!!!!
# 2012  : This is the number we want!!!!
# 2013  : This is the number we want!!!!
# 2014  : This is the number we want!!!!
# 2016  : This is the number we want!!!!
# 2017  : This is the number we want!!!!
# 2018  : This is the number we want!!!!
# 2019  : This is the number we want!!!!
# 2021  : This is the number we want!!!!
# 2022  : This is the number we want!!!!
# 2023  : This is the number we want!!!!
# 2024  : This is the number we want!!!!
# 2026  : This is the number we want!!!!
# 2027  : This is the number we want!!!!
# 2028  : This is the number we want!!!!
# 2029  : This is the number we want!!!!
# 2030  : This is the number we want!!!!
# 2031  : This is the number we want!!!!
# 2032  : This is the number we want!!!!
# 2033  : This is the number we want!!!!
# 2034  : This is the number we want!!!!
# 2036  : This is the number we want!!!!
# 2037  : This is the number we want!!!!
# 2038  : This is the number we want!!!!
# 2039  : This is the number we want!!!!
# 2041  : This is the number we want!!!!
# 2042  : This is the number we want!!!!
# 2043  : This is the number we want!!!!
# 2044  : This is the number we want!!!!
# 2046  : This is the number we want!!!!
# 2047  : This is the number we want!!!!
# 2048  : This is the number we want!!!!
# 2049  : This is the number we want!!!!
# 2051  : This is the number we want!!!!
# 2052  : This is the number we want!!!!
# 2053  : This is the number we want!!!!
# 2054  : This is the number we want!!!!
# 2056  : This is the number we want!!!!
# 2057  : This is the number we want!!!!
# 2058  : This is the number we want!!!!
# 2059  : This is the number we want!!!!
# 2061  : This is the number we want!!!!
# 2062  : This is the number we want!!!!
# 2063  : This is the number we want!!!!
# 2064  : This is the number we want!!!!
# 2065  : This is the number we want!!!!
# 2066  : This is the number we want!!!!
# 2067  : This is the number we want!!!!
# 2068  : This is the number we want!!!!
# 2069  : This is the number we want!!!!
# 2071  : This is the number we want!!!!
# 2072  : This is the number we want!!!!
# 2073  : This is the number we want!!!!
# 2074  : This is the number we want!!!!
# 2076  : This is the number we want!!!!
# 2077  : This is the number we want!!!!
# 2078  : This is the number we want!!!!
# 2079  : This is the number we want!!!!
# 2081  : This is the number we want!!!!
# 2082  : This is the number we want!!!!
# 2083  : This is the number we want!!!!
# 2084  : This is the number we want!!!!
# 2086  : This is the number we want!!!!
# 2087  : This is the number we want!!!!
# 2088  : This is the number we want!!!!
# 2089  : This is the number we want!!!!
# 2091  : This is the number we want!!!!
# 2092  : This is the number we want!!!!
# 2093  : This is the number we want!!!!
# 2094  : This is the number we want!!!!
# 2096  : This is the number we want!!!!
# 2097  : This is the number we want!!!!
# 2098  : This is the number we want!!!!
# 2099  : This is the number we want!!!!
# 2100  : This is the number we want!!!!
# 2101  : This is the number we want!!!!
# 2102  : This is the number we want!!!!
# 2103  : This is the number we want!!!!
# 2104  : This is the number we want!!!!
# 2106  : This is the number we want!!!!
# 2107  : This is the number we want!!!!
# 2108  : This is the number we want!!!!
# 2109  : This is the number we want!!!!
# 2111  : This is the number we want!!!!
# 2112  : This is the number we want!!!!
# 2113  : This is the number we want!!!!
# 2114  : This is the number we want!!!!
# 2116  : This is the number we want!!!!
# 2117  : This is the number we want!!!!
# 2118  : This is the number we want!!!!
# 2119  : This is the number we want!!!!
# 2121  : This is the number we want!!!!
# 2122  : This is the number we want!!!!
# 2123  : This is the number we want!!!!
# 2124  : This is the number we want!!!!
# 2126  : This is the number we want!!!!
# 2127  : This is the number we want!!!!
# 2128  : This is the number we want!!!!
# 2129  : This is the number we want!!!!
# 2131  : This is the number we want!!!!
# 2132  : This is the number we want!!!!
# 2133  : This is the number we want!!!!
# 2134  : This is the number we want!!!!
# 2135  : This is the number we want!!!!
# 2136  : This is the number we want!!!!
# 2137  : This is the number we want!!!!
# 2138  : This is the number we want!!!!
# 2139  : This is the number we want!!!!
# 2141  : This is the number we want!!!!
# 2142  : This is the number we want!!!!
# 2143  : This is the number we want!!!!
# 2144  : This is the number we want!!!!
# 2146  : This is the number we want!!!!
# 2147  : This is the number we want!!!!
# 2148  : This is the number we want!!!!
# 2149  : This is the number we want!!!!
# 2151  : This is the number we want!!!!
# 2152  : This is the number we want!!!!
# 2153  : This is the number we want!!!!
# 2154  : This is the number we want!!!!
# 2156  : This is the number we want!!!!
# 2157  : This is the number we want!!!!
# 2158  : This is the number we want!!!!
# 2159  : This is the number we want!!!!
# 2161  : This is the number we want!!!!
# 2162  : This is the number we want!!!!
# 2163  : This is the number we want!!!!
# 2164  : This is the number we want!!!!
# 2166  : This is the number we want!!!!
# 2167  : This is the number we want!!!!
# 2168  : This is the number we want!!!!
# 2169  : This is the number we want!!!!
# 2170  : This is the number we want!!!!
# 2171  : This is the number we want!!!!
# 2172  : This is the number we want!!!!
# 2173  : This is the number we want!!!!
# 2174  : This is the number we want!!!!
# 2176  : This is the number we want!!!!
# 2177  : This is the number we want!!!!
# 2178  : This is the number we want!!!!
# 2179  : This is the number we want!!!!
# 2181  : This is the number we want!!!!
# 2182  : This is the number we want!!!!
# 2183  : This is the number we want!!!!
# 2184  : This is the number we want!!!!
# 2186  : This is the number we want!!!!
# 2187  : This is the number we want!!!!
# 2188  : This is the number we want!!!!
# 2189  : This is the number we want!!!!
# 2191  : This is the number we want!!!!
# 2192  : This is the number we want!!!!
# 2193  : This is the number we want!!!!
# 2194  : This is the number we want!!!!
# 2196  : This is the number we want!!!!
# 2197  : This is the number we want!!!!
# 2198  : This is the number we want!!!!
# 2199  : This is the number we want!!!!
# 2201  : This is the number we want!!!!
# 2202  : This is the number we want!!!!
# 2203  : This is the number we want!!!!
# 2204  : This is the number we want!!!!
# 2205  : This is the number we want!!!!
# 2206  : This is the number we want!!!!
# 2207  : This is the number we want!!!!
# 2208  : This is the number we want!!!!
# 2209  : This is the number we want!!!!
# 2211  : This is the number we want!!!!
# 2212  : This is the number we want!!!!
# 2213  : This is the number we want!!!!
# 2214  : This is the number we want!!!!
# 2216  : This is the number we want!!!!
# 2217  : This is the number we want!!!!
# 2218  : This is the number we want!!!!
# 2219  : This is the number we want!!!!
# 2221  : This is the number we want!!!!
# 2222  : This is the number we want!!!!
# 2223  : This is the number we want!!!!
# 2224  : This is the number we want!!!!
# 2226  : This is the number we want!!!!
# 2227  : This is the number we want!!!!
# 2228  : This is the number we want!!!!
# 2229  : This is the number we want!!!!
# 2231  : This is the number we want!!!!
# 2232  : This is the number we want!!!!
# 2233  : This is the number we want!!!!
# 2234  : This is the number we want!!!!
# 2236  : This is the number we want!!!!
# 2237  : This is the number we want!!!!
# 2238  : This is the number we want!!!!
# 2239  : This is the number we want!!!!
# 2240  : This is the number we want!!!!
# 2241  : This is the number we want!!!!
# 2242  : This is the number we want!!!!
# 2243  : This is the number we want!!!!
# 2244  : This is the number we want!!!!
# 2246  : This is the number we want!!!!
# 2247  : This is the number we want!!!!
# 2248  : This is the number we want!!!!
# 2249  : This is the number we want!!!!
# 2251  : This is the number we want!!!!
# 2252  : This is the number we want!!!!
# 2253  : This is the number we want!!!!
# 2254  : This is the number we want!!!!
# 2256  : This is the number we want!!!!
# 2257  : This is the number we want!!!!
# 2258  : This is the number we want!!!!
# 2259  : This is the number we want!!!!
# 2261  : This is the number we want!!!!
# 2262  : This is the number we want!!!!
# 2263  : This is the number we want!!!!
# 2264  : This is the number we want!!!!
# 2266  : This is the number we want!!!!
# 2267  : This is the number we want!!!!
# 2268  : This is the number we want!!!!
# 2269  : This is the number we want!!!!
# 2271  : This is the number we want!!!!
# 2272  : This is the number we want!!!!
# 2273  : This is the number we want!!!!
# 2274  : This is the number we want!!!!
# 2275  : This is the number we want!!!!
# 2276  : This is the number we want!!!!
# 2277  : This is the number we want!!!!
# 2278  : This is the number we want!!!!
# 2279  : This is the number we want!!!!
# 2281  : This is the number we want!!!!
# 2282  : This is the number we want!!!!
# 2283  : This is the number we want!!!!
# 2284  : This is the number we want!!!!
# 2286  : This is the number we want!!!!
# 2287  : This is the number we want!!!!
# 2288  : This is the number we want!!!!
# 2289  : This is the number we want!!!!
# 2291  : This is the number we want!!!!
# 2292  : This is the number we want!!!!
# 2293  : This is the number we want!!!!
# 2294  : This is the number we want!!!!
# 2296  : This is the number we want!!!!
# 2297  : This is the number we want!!!!
# 2298  : This is the number we want!!!!
# 2299  : This is the number we want!!!!
# 2301  : This is the number we want!!!!
# 2302  : This is the number we want!!!!
# 2303  : This is the number we want!!!!
# 2304  : This is the number we want!!!!
# 2306  : This is the number we want!!!!
# 2307  : This is the number we want!!!!
# 2308  : This is the number we want!!!!
# 2309  : This is the number we want!!!!
# 2310  : This is the number we want!!!!
# 2311  : This is the number we want!!!!
# 2312  : This is the number we want!!!!
# 2313  : This is the number we want!!!!
# 2314  : This is the number we want!!!!
# 2316  : This is the number we want!!!!
# 2317  : This is the number we want!!!!
# 2318  : This is the number we want!!!!
# 2319  : This is the number we want!!!!
# 2321  : This is the number we want!!!!
# 2322  : This is the number we want!!!!
# 2323  : This is the number we want!!!!
# 2324  : This is the number we want!!!!
# 2326  : This is the number we want!!!!
# 2327  : This is the number we want!!!!
# 2328  : This is the number we want!!!!
# 2329  : This is the number we want!!!!
# 2331  : This is the number we want!!!!
# 2332  : This is the number we want!!!!
# 2333  : This is the number we want!!!!
# 2334  : This is the number we want!!!!
# 2336  : This is the number we want!!!!
# 2337  : This is the number we want!!!!
# 2338  : This is the number we want!!!!
# 2339  : This is the number we want!!!!
# 2341  : This is the number we want!!!!
# 2342  : This is the number we want!!!!
# 2343  : This is the number we want!!!!
# 2344  : This is the number we want!!!!
# 2345  : This is the number we want!!!!
# 2346  : This is the number we want!!!!
# 2347  : This is the number we want!!!!
# 2348  : This is the number we want!!!!
# 2349  : This is the number we want!!!!
# 2351  : This is the number we want!!!!
# 2352  : This is the number we want!!!!
# 2353  : This is the number we want!!!!
# 2354  : This is the number we want!!!!
# 2356  : This is the number we want!!!!
# 2357  : This is the number we want!!!!
# 2358  : This is the number we want!!!!
# 2359  : This is the number we want!!!!
# 2361  : This is the number we want!!!!
# 2362  : This is the number we want!!!!
# 2363  : This is the number we want!!!!
# 2364  : This is the number we want!!!!
# 2366  : This is the number we want!!!!
# 2367  : This is the number we want!!!!
# 2368  : This is the number we want!!!!
# 2369  : This is the number we want!!!!
# 2371  : This is the number we want!!!!
# 2372  : This is the number we want!!!!
# 2373  : This is the number we want!!!!
# 2374  : This is the number we want!!!!
# 2376  : This is the number we want!!!!
# 2377  : This is the number we want!!!!
# 2378  : This is the number we want!!!!
# 2379  : This is the number we want!!!!
# 2380  : This is the number we want!!!!
# 2381  : This is the number we want!!!!
# 2382  : This is the number we want!!!!
# 2383  : This is the number we want!!!!
# 2384  : This is the number we want!!!!
# 2386  : This is the number we want!!!!
# 2387  : This is the number we want!!!!
# 2388  : This is the number we want!!!!
# 2389  : This is the number we want!!!!
# 2391  : This is the number we want!!!!
# 2392  : This is the number we want!!!!
# 2393  : This is the number we want!!!!
# 2394  : This is the number we want!!!!
# 2396  : This is the number we want!!!!
# 2397  : This is the number we want!!!!
# 2398  : This is the number we want!!!!
# 2399  : This is the number we want!!!!
# 2401  : This is the number we want!!!!
# 2402  : This is the number we want!!!!
# 2403  : This is the number we want!!!!
# 2404  : This is the number we want!!!!
# 2406  : This is the number we want!!!!
# 2407  : This is the number we want!!!!
# 2408  : This is the number we want!!!!
# 2409  : This is the number we want!!!!
# 2411  : This is the number we want!!!!
# 2412  : This is the number we want!!!!
# 2413  : This is the number we want!!!!
# 2414  : This is the number we want!!!!
# 2415  : This is the number we want!!!!
# 2416  : This is the number we want!!!!
# 2417  : This is the number we want!!!!
# 2418  : This is the number we want!!!!
# 2419  : This is the number we want!!!!
# 2421  : This is the number we want!!!!
# 2422  : This is the number we want!!!!
# 2423  : This is the number we want!!!!
# 2424  : This is the number we want!!!!
# 2426  : This is the number we want!!!!
# 2427  : This is the number we want!!!!
# 2428  : This is the number we want!!!!
# 2429  : This is the number we want!!!!
# 2431  : This is the number we want!!!!
# 2432  : This is the number we want!!!!
# 2433  : This is the number we want!!!!
# 2434  : This is the number we want!!!!
# 2436  : This is the number we want!!!!
# 2437  : This is the number we want!!!!
# 2438  : This is the number we want!!!!
# 2439  : This is the number we want!!!!
# 2441  : This is the number we want!!!!
# 2442  : This is the number we want!!!!
# 2443  : This is the number we want!!!!
# 2444  : This is the number we want!!!!
# 2446  : This is the number we want!!!!
# 2447  : This is the number we want!!!!
# 2448  : This is the number we want!!!!
# 2449  : This is the number we want!!!!
# 2450  : This is the number we want!!!!
# 2451  : This is the number we want!!!!
# 2452  : This is the number we want!!!!
# 2453  : This is the number we want!!!!
# 2454  : This is the number we want!!!!
# 2456  : This is the number we want!!!!
# 2457  : This is the number we want!!!!
# 2458  : This is the number we want!!!!
# 2459  : This is the number we want!!!!
# 2461  : This is the number we want!!!!
# 2462  : This is the number we want!!!!
# 2463  : This is the number we want!!!!
# 2464  : This is the number we want!!!!
# 2466  : This is the number we want!!!!
# 2467  : This is the number we want!!!!
# 2468  : This is the number we want!!!!
# 2469  : This is the number we want!!!!
# 2471  : This is the number we want!!!!
# 2472  : This is the number we want!!!!
# 2473  : This is the number we want!!!!
# 2474  : This is the number we want!!!!
# 2476  : This is the number we want!!!!
# 2477  : This is the number we want!!!!
# 2478  : This is the number we want!!!!
# 2479  : This is the number we want!!!!
# 2481  : This is the number we want!!!!
# 2482  : This is the number we want!!!!
# 2483  : This is the number we want!!!!
# 2484  : This is the number we want!!!!
# 2485  : This is the number we want!!!!
# 2486  : This is the number we want!!!!
# 2487  : This is the number we want!!!!
# 2488  : This is the number we want!!!!
# 2489  : This is the number we want!!!!
# 2491  : This is the number we want!!!!
# 2492  : This is the number we want!!!!
# 2493  : This is the number we want!!!!
# 2494  : This is the number we want!!!!
# 2496  : This is the number we want!!!!
# 2497  : This is the number we want!!!!
# 2498  : This is the number we want!!!!
# 2499  : This is the number we want!!!!
# 2501  : This is the number we want!!!!
# 2502  : This is the number we want!!!!
# 2503  : This is the number we want!!!!
# 2504  : This is the number we want!!!!
# 2506  : This is the number we want!!!!
# 2507  : This is the number we want!!!!
# 2508  : This is the number we want!!!!
# 2509  : This is the number we want!!!!
# 2511  : This is the number we want!!!!
# 2512  : This is the number we want!!!!
# 2513  : This is the number we want!!!!
# 2514  : This is the number we want!!!!
# 2516  : This is the number we want!!!!
# 2517  : This is the number we want!!!!
# 2518  : This is the number we want!!!!
# 2519  : This is the number we want!!!!
# 2520  : This is the number we want!!!!
# 2521  : This is the number we want!!!!
# 2522  : This is the number we want!!!!
# 2523  : This is the number we want!!!!
# 2524  : This is the number we want!!!!
# 2526  : This is the number we want!!!!
# 2527  : This is the number we want!!!!
# 2528  : This is the number we want!!!!
# 2529  : This is the number we want!!!!
# 2531  : This is the number we want!!!!
# 2532  : This is the number we want!!!!
# 2533  : This is the number we want!!!!
# 2534  : This is the number we want!!!!
# 2536  : This is the number we want!!!!
# 2537  : This is the number we want!!!!
# 2538  : This is the number we want!!!!
# 2539  : This is the number we want!!!!
# 2541  : This is the number we want!!!!
# 2542  : This is the number we want!!!!
# 2543  : This is the number we want!!!!
# 2544  : This is the number we want!!!!
# 2546  : This is the number we want!!!!
# 2547  : This is the number we want!!!!
# 2548  : This is the number we want!!!!
# 2549  : This is the number we want!!!!
# 2551  : This is the number we want!!!!
# 2552  : This is the number we want!!!!
# 2553  : This is the number we want!!!!
# 2554  : This is the number we want!!!!
# 2555  : This is the number we want!!!!
# 2556  : This is the number we want!!!!
# 2557  : This is the number we want!!!!
# 2558  : This is the number we want!!!!
# 2559  : This is the number we want!!!!
# 2561  : This is the number we want!!!!
# 2562  : This is the number we want!!!!
# 2563  : This is the number we want!!!!
# 2564  : This is the number we want!!!!
# 2566  : This is the number we want!!!!
# 2567  : This is the number we want!!!!
# 2568  : This is the number we want!!!!
# 2569  : This is the number we want!!!!
# 2571  : This is the number we want!!!!
# 2572  : This is the number we want!!!!
# 2573  : This is the number we want!!!!
# 2574  : This is the number we want!!!!
# 2576  : This is the number we want!!!!
# 2577  : This is the number we want!!!!
# 2578  : This is the number we want!!!!
# 2579  : This is the number we want!!!!
# 2581  : This is the number we want!!!!
# 2582  : This is the number we want!!!!
# 2583  : This is the number we want!!!!
# 2584  : This is the number we want!!!!
# 2586  : This is the number we want!!!!
# 2587  : This is the number we want!!!!
# 2588  : This is the number we want!!!!
# 2589  : This is the number we want!!!!
# 2590  : This is the number we want!!!!
# 2591  : This is the number we want!!!!
# 2592  : This is the number we want!!!!
# 2593  : This is the number we want!!!!
# 2594  : This is the number we want!!!!
# 2596  : This is the number we want!!!!
# 2597  : This is the number we want!!!!
# 2598  : This is the number we want!!!!
# 2599  : This is the number we want!!!!
# 2601  : This is the number we want!!!!
# 2602  : This is the number we want!!!!
# 2603  : This is the number we want!!!!
# 2604  : This is the number we want!!!!
# 2606  : This is the number we want!!!!
# 2607  : This is the number we want!!!!
# 2608  : This is the number we want!!!!
# 2609  : This is the number we want!!!!
# 2611  : This is the number we want!!!!
# 2612  : This is the number we want!!!!
# 2613  : This is the number we want!!!!
# 2614  : This is the number we want!!!!
# 2616  : This is the number we want!!!!
# 2617  : This is the number we want!!!!
# 2618  : This is the number we want!!!!
# 2619  : This is the number we want!!!!
# 2621  : This is the number we want!!!!
# 2622  : This is the number we want!!!!
# 2623  : This is the number we want!!!!
# 2624  : This is the number we want!!!!
# 2625  : This is the number we want!!!!
# 2626  : This is the number we want!!!!
# 2627  : This is the number we want!!!!
# 2628  : This is the number we want!!!!
# 2629  : This is the number we want!!!!
# 2631  : This is the number we want!!!!
# 2632  : This is the number we want!!!!
# 2633  : This is the number we want!!!!
# 2634  : This is the number we want!!!!
# 2636  : This is the number we want!!!!
# 2637  : This is the number we want!!!!
# 2638  : This is the number we want!!!!
# 2639  : This is the number we want!!!!
# 2641  : This is the number we want!!!!
# 2642  : This is the number we want!!!!
# 2643  : This is the number we want!!!!
# 2644  : This is the number we want!!!!
# 2646  : This is the number we want!!!!
# 2647  : This is the number we want!!!!
# 2648  : This is the number we want!!!!
# 2649  : This is the number we want!!!!
# 2651  : This is the number we want!!!!
# 2652  : This is the number we want!!!!
# 2653  : This is the number we want!!!!
# 2654  : This is the number we want!!!!
# 2656  : This is the number we want!!!!
# 2657  : This is the number we want!!!!
# 2658  : This is the number we want!!!!
# 2659  : This is the number we want!!!!
# 2660  : This is the number we want!!!!
# 2661  : This is the number we want!!!!
# 2662  : This is the number we want!!!!
# 2663  : This is the number we want!!!!
# 2664  : This is the number we want!!!!
# 2666  : This is the number we want!!!!
# 2667  : This is the number we want!!!!
# 2668  : This is the number we want!!!!
# 2669  : This is the number we want!!!!
# 2671  : This is the number we want!!!!
# 2672  : This is the number we want!!!!
# 2673  : This is the number we want!!!!
# 2674  : This is the number we want!!!!
# 2676  : This is the number we want!!!!
# 2677  : This is the number we want!!!!
# 2678  : This is the number we want!!!!
# 2679  : This is the number we want!!!!
# 2681  : This is the number we want!!!!
# 2682  : This is the number we want!!!!
# 2683  : This is the number we want!!!!
# 2684  : This is the number we want!!!!
# 2686  : This is the number we want!!!!
# 2687  : This is the number we want!!!!
# 2688  : This is the number we want!!!!
# 2689  : This is the number we want!!!!
# 2691  : This is the number we want!!!!
# 2692  : This is the number we want!!!!
# 2693  : This is the number we want!!!!
# 2694  : This is the number we want!!!!
# 2695  : This is the number we want!!!!
# 2696  : This is the number we want!!!!
# 2697  : This is the number we want!!!!
# 2698  : This is the number we want!!!!
# 2699  : This is the number we want!!!!
# 2701  : This is the number we want!!!!
# 2702  : This is the number we want!!!!
# 2703  : This is the number we want!!!!
# 2704  : This is the number we want!!!!
# 2706  : This is the number we want!!!!
# 2707  : This is the number we want!!!!
# 2708  : This is the number we want!!!!
# 2709  : This is the number we want!!!!
# 2711  : This is the number we want!!!!
# 2712  : This is the number we want!!!!
# 2713  : This is the number we want!!!!
# 2714  : This is the number we want!!!!
# 2716  : This is the number we want!!!!
# 2717  : This is the number we want!!!!
# 2718  : This is the number we want!!!!
# 2719  : This is the number we want!!!!
# 2721  : This is the number we want!!!!
# 2722  : This is the number we want!!!!
# 2723  : This is the number we want!!!!
# 2724  : This is the number we want!!!!
# 2726  : This is the number we want!!!!
# 2727  : This is the number we want!!!!
# 2728  : This is the number we want!!!!
# 2729  : This is the number we want!!!!
# 2730  : This is the number we want!!!!
# 2731  : This is the number we want!!!!
# 2732  : This is the number we want!!!!
# 2733  : This is the number we want!!!!
# 2734  : This is the number we want!!!!
# 2736  : This is the number we want!!!!
# 2737  : This is the number we want!!!!
# 2738  : This is the number we want!!!!
# 2739  : This is the number we want!!!!
# 2741  : This is the number we want!!!!
# 2742  : This is the number we want!!!!
# 2743  : This is the number we want!!!!
# 2744  : This is the number we want!!!!
# 2746  : This is the number we want!!!!
# 2747  : This is the number we want!!!!
# 2748  : This is the number we want!!!!
# 2749  : This is the number we want!!!!
# 2751  : This is the number we want!!!!
# 2752  : This is the number we want!!!!
# 2753  : This is the number we want!!!!
# 2754  : This is the number we want!!!!
# 2756  : This is the number we want!!!!
# 2757  : This is the number we want!!!!
# 2758  : This is the number we want!!!!
# 2759  : This is the number we want!!!!
# 2761  : This is the number we want!!!!
# 2762  : This is the number we want!!!!
# 2763  : This is the number we want!!!!
# 2764  : This is the number we want!!!!
# 2765  : This is the number we want!!!!
# 2766  : This is the number we want!!!!
# 2767  : This is the number we want!!!!
# 2768  : This is the number we want!!!!
# 2769  : This is the number we want!!!!
# 2771  : This is the number we want!!!!
# 2772  : This is the number we want!!!!
# 2773  : This is the number we want!!!!
# 2774  : This is the number we want!!!!
# 2776  : This is the number we want!!!!
# 2777  : This is the number we want!!!!
# 2778  : This is the number we want!!!!
# 2779  : This is the number we want!!!!
# 2781  : This is the number we want!!!!
# 2782  : This is the number we want!!!!
# 2783  : This is the number we want!!!!
# 2784  : This is the number we want!!!!
# 2786  : This is the number we want!!!!
# 2787  : This is the number we want!!!!
# 2788  : This is the number we want!!!!
# 2789  : This is the number we want!!!!
# 2791  : This is the number we want!!!!
# 2792  : This is the number we want!!!!
# 2793  : This is the number we want!!!!
# 2794  : This is the number we want!!!!
# 2796  : This is the number we want!!!!
# 2797  : This is the number we want!!!!
# 2798  : This is the number we want!!!!
# 2799  : This is the number we want!!!!
# 2800  : This is the number we want!!!!
# 2801  : This is the number we want!!!!
# 2802  : This is the number we want!!!!
# 2803  : This is the number we want!!!!
# 2804  : This is the number we want!!!!
# 2806  : This is the number we want!!!!
# 2807  : This is the number we want!!!!
# 2808  : This is the number we want!!!!
# 2809  : This is the number we want!!!!
# 2811  : This is the number we want!!!!
# 2812  : This is the number we want!!!!
# 2813  : This is the number we want!!!!
# 2814  : This is the number we want!!!!
# 2816  : This is the number we want!!!!
# 2817  : This is the number we want!!!!
# 2818  : This is the number we want!!!!
# 2819  : This is the number we want!!!!
# 2821  : This is the number we want!!!!
# 2822  : This is the number we want!!!!
# 2823  : This is the number we want!!!!
# 2824  : This is the number we want!!!!
# 2826  : This is the number we want!!!!
# 2827  : This is the number we want!!!!
# 2828  : This is the number we want!!!!
# 2829  : This is the number we want!!!!
# 2831  : This is the number we want!!!!
# 2832  : This is the number we want!!!!
# 2833  : This is the number we want!!!!
# 2834  : This is the number we want!!!!
# 2835  : This is the number we want!!!!
# 2836  : This is the number we want!!!!
# 2837  : This is the number we want!!!!
# 2838  : This is the number we want!!!!
# 2839  : This is the number we want!!!!
# 2841  : This is the number we want!!!!
# 2842  : This is the number we want!!!!
# 2843  : This is the number we want!!!!
# 2844  : This is the number we want!!!!
# 2846  : This is the number we want!!!!
# 2847  : This is the number we want!!!!
# 2848  : This is the number we want!!!!
# 2849  : This is the number we want!!!!
# 2851  : This is the number we want!!!!
# 2852  : This is the number we want!!!!
# 2853  : This is the number we want!!!!
# 2854  : This is the number we want!!!!
# 2856  : This is the number we want!!!!
# 2857  : This is the number we want!!!!
# 2858  : This is the number we want!!!!
# 2859  : This is the number we want!!!!
# 2861  : This is the number we want!!!!
# 2862  : This is the number we want!!!!
# 2863  : This is the number we want!!!!
# 2864  : This is the number we want!!!!
# 2866  : This is the number we want!!!!
# 2867  : This is the number we want!!!!
# 2868  : This is the number we want!!!!
# 2869  : This is the number we want!!!!
# 2870  : This is the number we want!!!!
# 2871  : This is the number we want!!!!
# 2872  : This is the number we want!!!!
# 2873  : This is the number we want!!!!
# 2874  : This is the number we want!!!!
# 2876  : This is the number we want!!!!
# 2877  : This is the number we want!!!!
# 2878  : This is the number we want!!!!
# 2879  : This is the number we want!!!!
# 2881  : This is the number we want!!!!
# 2882  : This is the number we want!!!!
# 2883  : This is the number we want!!!!
# 2884  : This is the number we want!!!!
# 2886  : This is the number we want!!!!
# 2887  : This is the number we want!!!!
# 2888  : This is the number we want!!!!
# 2889  : This is the number we want!!!!
# 2891  : This is the number we want!!!!
# 2892  : This is the number we want!!!!
# 2893  : This is the number we want!!!!
# 2894  : This is the number we want!!!!
# 2896  : This is the number we want!!!!
# 2897  : This is the number we want!!!!
# 2898  : This is the number we want!!!!
# 2899  : This is the number we want!!!!
# 2901  : This is the number we want!!!!
# 2902  : This is the number we want!!!!
# 2903  : This is the number we want!!!!
# 2904  : This is the number we want!!!!
# 2905  : This is the number we want!!!!
# 2906  : This is the number we want!!!!
# 2907  : This is the number we want!!!!
# 2908  : This is the number we want!!!!
# 2909  : This is the number we want!!!!
# 2911  : This is the number we want!!!!
# 2912  : This is the number we want!!!!
# 2913  : This is the number we want!!!!
# 2914  : This is the number we want!!!!
# 2916  : This is the number we want!!!!
# 2917  : This is the number we want!!!!
# 2918  : This is the number we want!!!!
# 2919  : This is the number we want!!!!
# 2921  : This is the number we want!!!!
# 2922  : This is the number we want!!!!
# 2923  : This is the number we want!!!!
# 2924  : This is the number we want!!!!
# 2926  : This is the number we want!!!!
# 2927  : This is the number we want!!!!
# 2928  : This is the number we want!!!!
# 2929  : This is the number we want!!!!
# 2931  : This is the number we want!!!!
# 2932  : This is the number we want!!!!
# 2933  : This is the number we want!!!!
# 2934  : This is the number we want!!!!
# 2936  : This is the number we want!!!!
# 2937  : This is the number we want!!!!
# 2938  : This is the number we want!!!!
# 2939  : This is the number we want!!!!
# 2940  : This is the number we want!!!!
# 2941  : This is the number we want!!!!
# 2942  : This is the number we want!!!!
# 2943  : This is the number we want!!!!
# 2944  : This is the number we want!!!!
# 2946  : This is the number we want!!!!
# 2947  : This is the number we want!!!!
# 2948  : This is the number we want!!!!
# 2949  : This is the number we want!!!!
# 2951  : This is the number we want!!!!
# 2952  : This is the number we want!!!!
# 2953  : This is the number we want!!!!
# 2954  : This is the number we want!!!!
# 2956  : This is the number we want!!!!
# 2957  : This is the number we want!!!!
# 2958  : This is the number we want!!!!
# 2959  : This is the number we want!!!!
# 2961  : This is the number we want!!!!
# 2962  : This is the number we want!!!!
# 2963  : This is the number we want!!!!
# 2964  : This is the number we want!!!!
# 2966  : This is the number we want!!!!
# 2967  : This is the number we want!!!!
# 2968  : This is the number we want!!!!
# 2969  : This is the number we want!!!!
# 2971  : This is the number we want!!!!
# 2972  : This is the number we want!!!!
# 2973  : This is the number we want!!!!
# 2974  : This is the number we want!!!!
# 2975  : This is the number we want!!!!
# 2976  : This is the number we want!!!!
# 2977  : This is the number we want!!!!
# 2978  : This is the number we want!!!!
# 2979  : This is the number we want!!!!
# 2981  : This is the number we want!!!!
# 2982  : This is the number we want!!!!
# 2983  : This is the number we want!!!!
# 2984  : This is the number we want!!!!
# 2986  : This is the number we want!!!!
# 2987  : This is the number we want!!!!
# 2988  : This is the number we want!!!!
# 2989  : This is the number we want!!!!
# 2991  : This is the number we want!!!!
# 2992  : This is the number we want!!!!
# 2993  : This is the number we want!!!!
# 2994  : This is the number we want!!!!
# 2996  : This is the number we want!!!!
# 2997  : This is the number we want!!!!
# 2998  : This is the number we want!!!!
# 2999  : This is the number we want!!!!
# 3001  : This is the number we want!!!!
# 3002  : This is the number we want!!!!
# 3003  : This is the number we want!!!!
# 3004  : This is the number we want!!!!
# 3006  : This is the number we want!!!!
# 3007  : This is the number we want!!!!
# 3008  : This is the number we want!!!!
# 3009  : This is the number we want!!!!
# 3010  : This is the number we want!!!!
# 3011  : This is the number we want!!!!
# 3012  : This is the number we want!!!!
# 3013  : This is the number we want!!!!
# 3014  : This is the number we want!!!!
# 3016  : This is the number we want!!!!
# 3017  : This is the number we want!!!!
# 3018  : This is the number we want!!!!
# 3019  : This is the number we want!!!!
# 3021  : This is the number we want!!!!
# 3022  : This is the number we want!!!!
# 3023  : This is the number we want!!!!
# 3024  : This is the number we want!!!!
# 3026  : This is the number we want!!!!
# 3027  : This is the number we want!!!!
# 3028  : This is the number we want!!!!
# 3029  : This is the number we want!!!!
# 3031  : This is the number we want!!!!
# 3032  : This is the number we want!!!!
# 3033  : This is the number we want!!!!
# 3034  : This is the number we want!!!!
# 3036  : This is the number we want!!!!
# 3037  : This is the number we want!!!!
# 3038  : This is the number we want!!!!
# 3039  : This is the number we want!!!!
# 3041  : This is the number we want!!!!
# 3042  : This is the number we want!!!!
# 3043  : This is the number we want!!!!
# 3044  : This is the number we want!!!!
# 3045  : This is the number we want!!!!
# 3046  : This is the number we want!!!!
# 3047  : This is the number we want!!!!
# 3048  : This is the number we want!!!!
# 3049  : This is the number we want!!!!
# 3051  : This is the number we want!!!!
# 3052  : This is the number we want!!!!
# 3053  : This is the number we want!!!!
# 3054  : This is the number we want!!!!
# 3056  : This is the number we want!!!!
# 3057  : This is the number we want!!!!
# 3058  : This is the number we want!!!!
# 3059  : This is the number we want!!!!
# 3061  : This is the number we want!!!!
# 3062  : This is the number we want!!!!
# 3063  : This is the number we want!!!!
# 3064  : This is the number we want!!!!
# 3066  : This is the number we want!!!!
# 3067  : This is the number we want!!!!
# 3068  : This is the number we want!!!!
# 3069  : This is the number we want!!!!
# 3071  : This is the number we want!!!!
# 3072  : This is the number we want!!!!
# 3073  : This is the number we want!!!!
# 3074  : This is the number we want!!!!
# 3076  : This is the number we want!!!!
# 3077  : This is the number we want!!!!
# 3078  : This is the number we want!!!!
# 3079  : This is the number we want!!!!
# 3080  : This is the number we want!!!!
# 3081  : This is the number we want!!!!
# 3082  : This is the number we want!!!!
# 3083  : This is the number we want!!!!
# 3084  : This is the number we want!!!!
# 3086  : This is the number we want!!!!
# 3087  : This is the number we want!!!!
# 3088  : This is the number we want!!!!
# 3089  : This is the number we want!!!!
# 3091  : This is the number we want!!!!
# 3092  : This is the number we want!!!!
# 3093  : This is the number we want!!!!
# 3094  : This is the number we want!!!!
# 3096  : This is the number we want!!!!
# 3097  : This is the number we want!!!!
# 3098  : This is the number we want!!!!
# 3099  : This is the number we want!!!!
# 3101  : This is the number we want!!!!
# 3102  : This is the number we want!!!!
# 3103  : This is the number we want!!!!
# 3104  : This is the number we want!!!!
# 3106  : This is the number we want!!!!
# 3107  : This is the number we want!!!!
# 3108  : This is the number we want!!!!
# 3109  : This is the number we want!!!!
# 3111  : This is the number we want!!!!
# 3112  : This is the number we want!!!!
# 3113  : This is the number we want!!!!
# 3114  : This is the number we want!!!!
# 3115  : This is the number we want!!!!
# 3116  : This is the number we want!!!!
# 3117  : This is the number we want!!!!
# 3118  : This is the number we want!!!!
# 3119  : This is the number we want!!!!
# 3121  : This is the number we want!!!!
# 3122  : This is the number we want!!!!
# 3123  : This is the number we want!!!!
# 3124  : This is the number we want!!!!
# 3126  : This is the number we want!!!!
# 3127  : This is the number we want!!!!
# 3128  : This is the number we want!!!!
# 3129  : This is the number we want!!!!
# 3131  : This is the number we want!!!!
# 3132  : This is the number we want!!!!
# 3133  : This is the number we want!!!!
# 3134  : This is the number we want!!!!
# 3136  : This is the number we want!!!!
# 3137  : This is the number we want!!!!
# 3138  : This is the number we want!!!!
# 3139  : This is the number we want!!!!
# 3141  : This is the number we want!!!!
# 3142  : This is the number we want!!!!
# 3143  : This is the number we want!!!!
# 3144  : This is the number we want!!!!
# 3146  : This is the number we want!!!!
# 3147  : This is the number we want!!!!
# 3148  : This is the number we want!!!!
# 3149  : This is the number we want!!!!
# 3150  : This is the number we want!!!!
# 3151  : This is the number we want!!!!
# 3152  : This is the number we want!!!!
# 3153  : This is the number we want!!!!
# 3154  : This is the number we want!!!!
# 3156  : This is the number we want!!!!
# 3157  : This is the number we want!!!!
# 3158  : This is the number we want!!!!
# 3159  : This is the number we want!!!!
# 3161  : This is the number we want!!!!
# 3162  : This is the number we want!!!!
# 3163  : This is the number we want!!!!
# 3164  : This is the number we want!!!!
# 3166  : This is the number we want!!!!
# 3167  : This is the number we want!!!!
# 3168  : This is the number we want!!!!
# 3169  : This is the number we want!!!!
# 3171  : This is the number we want!!!!
# 3172  : This is the number we want!!!!
# 3173  : This is the number we want!!!!
# 3174  : This is the number we want!!!!
# 3176  : This is the number we want!!!!
# 3177  : This is the number we want!!!!
# 3178  : This is the number we want!!!!
# 3179  : This is the number we want!!!!
# 3181  : This is the number we want!!!!
# 3182  : This is the number we want!!!!
# 3183  : This is the number we want!!!!
# 3184  : This is the number we want!!!!
# 3185  : This is the number we want!!!!
# 3186  : This is the number we want!!!!
# 3187  : This is the number we want!!!!
# 3188  : This is the number we want!!!!
# 3189  : This is the number we want!!!!
# 3191  : This is the number we want!!!!
# 3192  : This is the number we want!!!!
# 3193  : This is the number we want!!!!
# 3194  : This is the number we want!!!!
# 3196  : This is the number we want!!!!
# 3197  : This is the number we want!!!!
# 3198  : This is the number we want!!!!
# 3199  : This is the number we want!!!!

# %% [markdown]
# #  Question 3
#
# Task: Create a function that computes the factorial of a specified integer. Display the result in a single line of output. For example, if the input is: 8 Then, the output should be: 40320 Question 3

# %%
# to compute factorial
n = int(input("Enter a number : "))
fact = 1

for i in range(1, n+1):
    fact = fact * i

print("The factorial of", n ,"is : ", fact)
# Out:
# Enter a number : 8
# The factorial of 8 is :  40320

# %% [markdown]
# # Question 4
# Task: Given an integer n, generate a dictionary with entries (i, i*i) for all integers from 1 to n (inclusive). Print the resulting dictionary. For example, if the input is: 8 Then, the output should be: {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64} Question 4

# %%
r={}
for i in range(1, 10):
    r.update({i : i*i})
print(r)
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81}

# %% [markdown]
# # Question 5
#
# Task: Create a program that reads a series of comma-separated numbers from the console, then generates and prints both a list and a tuple containing those numbers. For example, if the input is: 34,67,55,33,12,98 The output should be: ['34', '67', '55', '33', '12', '98'] ('34', '67', '55', '33', '12', '98') Question 5

# %%
# Prompt the user to input comma-separated numbers
input_values = input("Enter comma-separated numbers: ")

# Split the input string into a list of numbers (as strings)
numbers_list = input_values.split(",")

# Convert the list into a tuple
numbers_tuple = tuple(numbers_list)

# Print the results
print("List:", numbers_list)
print("Tuple:", numbers_tuple)
# Out:
# Enter comma-separated numbers: 34,45,67,89,23,45,68
# List: ['34', '45', '67', '89', '23', '45', '68']
# Tuple: ('34', '45', '67', '89', '23', '45', '68')

# %% [markdown]
# # Question 6
#
# Level 2
#
# Task:
# Write a program that calculates and prints values based on the formula:
# $ Q = \sqrt{\frac{2 \times C \times D}{H}} $
# Here, C and H are fixed constants with values 50 and 30, respectively. D is a variable whose values are input to the program as a comma-separated sequence. For example, if the input

# %%
import math

C=50
H=30
D=int(input("Enter the number D : "))
R=2*C*D

Q= math.sqrt(R/H)
print(Q)
# Out:
# Enter the number D : 10
# 5.773502691896258

# %% [markdown]
# Task: Create a class that has two methods:
#
# getString: To accept a string input from the console.
#
# printString: To display the string in uppercase.
# Include a simple test function to demonstrate the class methods.
